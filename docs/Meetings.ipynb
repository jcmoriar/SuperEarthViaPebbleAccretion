# %% [markdown]
# ##Feb 23, 2015
# ###Overview
# ####Pebble accretion
# - Paper
#     - Intro + methods written
#     - Results
#         - Computation done
#         - How best to plot?
#         - Writing ~1 week
#     - Discussion/Conclusion
#         - Should be fun to write done in another week
#         - Timing of giant planet formation and implications for system architecture.
#             - Does this imply that if a long period giant planet exists then super-Earths between ~1-2 AU should not?
#         - Continuous of formation of planetesimals rather than initial conditions.
# - Future work
#     - Can this single model explain the variety of exoplanetary systems we see?
#         - N-body simulations starting with surface densities from pebble accretion simulations
#         - Can it reproduce the range of MMEN slopes we see (raymond 2014)?
#         - Allow some migration?
#
# #### Stability of tightly packed systems
# - Question: Can dynamical instability of STIPs lead to the bimodal distribution of architectures we see (e.g. Ballard 2015)
#     - Method: N-body simulations
#         - First round: look at results of the simulations I've already run. I think a lot of information can be gleaned from these.
#             - Number of bodies over time.
#             - Number of observable bodies over time.
#             - Evolution of inclination.
#         - Second thing to do is look at this as a function of stellar mass. In particular Sarah Ballard is interested in M dwarfs and seeing if allowing for instabilities can reproduce the distribution of her sample.
#             - Computing time
#                 - Possibly some at UW
#                 - Omega at Yale might be easier
#                 - The problem is the duration of the sims - Gyrs.
#                     - Rory's intuiting says this is way overkill because most stuff happens early on but there seems to be some other works that disagree (e.g. Pu and Wu 2015, Maybe that other talk I saw at AAS)
#
# #### MMEN
# - Just something I was pondering: Is the MMEN the result of a lot of systems starting essentially the same way and evolving similarly or is it the result of differing initial conditions. They way I look at this on a plot is this: If you plot multi planet systems do they all occupy the same region of parameter space or does each system reside in a separate region which was determined by its initial conditions?

# %% [markdown]
# ####Paper Plots

# %%
include("../plots/quicklook.jl")
set_default_plot_size(25cm, 15cm)

# %%
plot_all("../data/planetesimalsize/")
# Out:
# Plot(...)

# %%
plot_all("../data/gasdiskmass/")
# Out:
# Plot(...)

# %%
plot_all("../data/pebblesize/")
# Out:
# Plot(...)

# %% [markdown]
# <img src="images/InwardFlux.png" />

# %% [markdown]
# <img src="images/period_dist.png" />
